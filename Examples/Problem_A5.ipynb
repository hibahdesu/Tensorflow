# %%
# =======================================================================================
# PROBLEM A5
#
# Build and train a neural network model using the Sunspots.csv dataset.
# Use MAE as the metrics of your neural network model.
# We provided code for normalizing the data. Please do not change the code.
# Do not use lambda layers in your model.
#
# The dataset used in this problem is downloaded from kaggle.com/robervalt/sunspots
#
# Desired MAE < 0.15 on the normalized dataset.
# ========================================================================================

import csv
import tensorflow as tf
import numpy as np
import urllib

# DO NOT CHANGE THIS CODE
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = tf.expand_dims(series, axis=-1)
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.shuffle(shuffle_buffer)
    ds = ds.map(lambda w: (w[:-1], w[1:]))
    return ds.batch(batch_size).prefetch(1)


def solution_A5():
    data_url = 'https://github.com/dicodingacademy/assets/raw/main/Simulation/machine_learning/sunspots.csv'
    urllib.request.urlretrieve(data_url, 'sunspots.csv')

    time_step = []
    sunspots = []

    with open('sunspots.csv') as csvfile:
      reader = csv.reader(csvfile, delimiter=',')
      next(reader)
      for row in reader:
        sunspots.append(float(row[2]))
        time_step.append(int(row[0]))

    series= np.array(sunspots)

    # Normalization Function. DO NOT CHANGE THIS CODE
    min=np.min(series)
    max=np.max(series)
    series -= min
    series /= max
    time=np.array(time_step)

    # DO NOT CHANGE THIS CODE
    split_time=3000


    time_train = time[:split_time]
    x_train = series[:split_time]
    time_valid = time[split_time:]
    x_valid = series[split_time:]

    # DO NOT CHANGE THIS CODE
    window_size=30
    batch_size=32
    shuffle_buffer_size=1000


    train_set=windowed_dataset(x_train, window_size=window_size,
                               batch_size=batch_size, shuffle_buffer=shuffle_buffer_size)


    model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(10, activation="relu"),
        tf.keras.layers.Dense(10, activation="relu"),
        tf.keras.layers.Dense(1)
    ])

    # YOUR CODE
    model.compile(loss='mae', optimizer=tf.keras.optimizers.SGD(learning_rate=1e-6, momentum=0.9))

    model.fit(train_set, epochs=100)

    return model


# The code below is to save your model as a .h5 file.
# It will be saved automatically in your Submission folder.
if __name__ == '__main__':
    # DO NOT CHANGE THIS CODE
    model=solution_A5()
    model.save("model_A5.h5")
# Out:
# Epoch 1/100
# 93/93 [==============================] - 3s 19ms/step - loss: 0.1031
# Epoch 2/100
# 93/93 [==============================] - 1s 4ms/step - loss: 0.1016
# Epoch 3/100
# 93/93 [==============================] - 1s 5ms/step - loss: 0.1002
# Epoch 4/100
# 93/93 [==============================] - 1s 5ms/step - loss: 0.0989
# Epoch 5/100
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0976
# Epoch 6/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0963
# Epoch 7/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0952
# Epoch 8/100
# 93/93 [==============================] - 0s 4ms/step - loss: 0.0941
# Epoch 9/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0930
# Epoch 10/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0920
# Epoch 11/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0911
# Epoch 12/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0902
# Epoch 13/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0893
# Epoch 14/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0886
# Epoch 15/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0878
# Epoch 16/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0871
# Epoch 17/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0864
# Epoch 18/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0857
# Epoch 19/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0851
# Epoch 20/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0845
# Epoch 21/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0839
# Epoch 22/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0834
# Epoch 23/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0829
# Epoch 24/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0824
# Epoch 25/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0820
# Epoch 26/100
# 93/93 [==============================] - 0s 4ms/step - loss: 0.0815
# Epoch 27/100
# 93/93 [==============================] - 1s 5ms/step - loss: 0.0811
# Epoch 28/100
# 93/93 [==============================] - 1s 5ms/step - loss: 0.0807
# Epoch 29/100
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0803
# Epoch 30/100
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0799
# Epoch 31/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0795
# Epoch 32/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0792
# Epoch 33/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0789
# Epoch 34/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0786
# Epoch 35/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0783
# Epoch 36/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0780
# Epoch 37/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0777
# Epoch 38/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0774
# Epoch 39/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0772
# Epoch 40/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0769
# Epoch 41/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0767
# Epoch 42/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0765
# Epoch 43/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0763
# Epoch 44/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0761
# Epoch 45/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0759
# Epoch 46/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0757
# Epoch 47/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0755
# Epoch 48/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0753
# Epoch 49/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0751
# Epoch 50/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0750
# Epoch 51/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0748
# Epoch 52/100
# 93/93 [==============================] - 0s 4ms/step - loss: 0.0747
# Epoch 53/100
# 93/93 [==============================] - 1s 5ms/step - loss: 0.0745
# Epoch 54/100
# 93/93 [==============================] - 1s 4ms/step - loss: 0.0744
# Epoch 55/100
# 93/93 [==============================] - 1s 7ms/step - loss: 0.0742
# Epoch 56/100
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0741
# Epoch 57/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0740
# Epoch 58/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0739
# Epoch 59/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0737
# Epoch 60/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0736
# Epoch 61/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0735
# Epoch 62/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0734
# Epoch 63/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0733
# Epoch 64/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0732
# Epoch 65/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0731
# Epoch 66/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0730
# Epoch 67/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0730
# Epoch 68/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0729
# Epoch 69/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0728
# Epoch 70/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0727
# Epoch 71/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0726
# Epoch 72/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0725
# Epoch 73/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0725
# Epoch 74/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0724
# Epoch 75/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0723
# Epoch 76/100
# 93/93 [==============================] - 1s 5ms/step - loss: 0.0723
# Epoch 77/100
# 93/93 [==============================] - 1s 5ms/step - loss: 0.0722
# Epoch 78/100
# 93/93 [==============================] - 1s 5ms/step - loss: 0.0721
# Epoch 79/100
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0721
# Epoch 80/100
# 93/93 [==============================] - 1s 6ms/step - loss: 0.0720
# Epoch 81/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0719
# Epoch 82/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0719
# Epoch 83/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0718
# Epoch 84/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0718
# Epoch 85/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0717
# Epoch 86/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0717
# Epoch 87/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0716
# Epoch 88/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0716
# Epoch 89/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0715
# Epoch 90/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0715
# Epoch 91/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0714
# Epoch 92/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0714
# Epoch 93/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0713
# Epoch 94/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0713
# Epoch 95/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0713
# Epoch 96/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0712
# Epoch 97/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0712
# Epoch 98/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0711
# Epoch 99/100
# 93/93 [==============================] - 0s 3ms/step - loss: 0.0711
# Epoch 100/100
# 93/93 [==============================] - 1s 5ms/step - loss: 0.0711
